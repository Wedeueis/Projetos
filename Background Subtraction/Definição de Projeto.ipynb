# %% [markdown]
# # CCM304M133 - Visão Computacional e Processamento de Imagens

# %% [markdown]
# ## Projeto Fase 1 - Dataset
#
# ### Aluno: Wedeueis Braz

# %% [markdown]
# Dataset para problemas de extração e modelagem de plano de fundo obtido em www.svcl.ucsd.edu/projects/background_subtraction/ucsdbgsub_dataset.htm. O projeto fará uso de videos com camera fixa de pedestres e/ou veiculos em transito.

# %%
import cv2
import matplotlib.pyplot as plt
% matplotlib inline

img = cv2.imread("traffic/frame_1.jpg", 0)
img2 = cv2.imread("traffic/frame_20.jpg", 0)
img3 = cv2.imread("traffic/frame_40.jpg", 0)

plt.imshow(img, cmap="gray")
plt.figure()
plt.imshow(img2, cmap="gray")
plt.figure()
plt.imshow(img3, cmap="gray")

# %%
img = cv2.imread("peds/frame_1.jpg", 0)
img2 = cv2.imread("peds/frame_20.jpg", 0)
img3 = cv2.imread("peds/frame_40.jpg", 0)

plt.imshow(img, cmap="gray")
plt.figure()
plt.imshow(img2, cmap="gray")
plt.figure()
plt.imshow(img3, cmap="gray")
