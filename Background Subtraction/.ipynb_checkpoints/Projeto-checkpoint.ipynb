# %% [markdown]
# # CCM304M133 - Visão Computacional e Processamento de Imagens

# %% [markdown]
# ## Projeto Fase 3 - Relatório
#
# ### Aluno: Wedeueis Braz

# %% [markdown]
# ## Problema: Detecção de objetos em movimento em vídeo
#
# Dada uma stream de vídeo usar técnicas de processamento de imagens para detectar objetos em movimento segmentando-os do plano de fundo e selecionando potenciais objetos de interesse.
# A solução poderá ser utilizada em vídeos de segurança para acionar a gravação da cena ou em vídeos de "homecare", onde o monitoramento de vulneráveis poderá alertar sobre situações de emergência.
# As técnicas utilizadas serão as vistas em sala de aula acrescidas de técnicas específicas para vídeos enquanto sequencias de imagens.

# %% [markdown]
# ## Dados
#
# Dataset de teste para problemas de extração e modelagem de plano de fundo obtido em
# www.svcl.ucsd.edu/projects/background_subtraction/ucsdbgsub_dataset.htm.
#
# O projeto faz uso de videos com camera fixa de pedestres e veiculos em transito,
# simulando uma camera de segurança em situação real.

# %% [markdown]
# #### Exemplos de imagens:
#
# Dataset de Pedestres:
# Imagens .jpg em nível de cinza de 232 x 152 pixels.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

def showfig(image, ucmap='gray', size=10):
    plt.figure(figsize=(size,size))
    imgplot=plt.imshow(image, ucmap)

img = cv2.imread("peds/frame_1.jpg", 0)

showfig(img)

# %%
#Conversão dos frames em um arquivo de vídeo .avi

# %%
from os.path import isfile, join
 
def convert_frames_to_video(pathIn,pathOut,fps):
    frame_array = []
    files = [f for f in os.listdir(pathIn) if isfile(join(pathIn, f))]
 
    #for sorting the file names properly
    files.sort(key = lambda x: int(x[6:-4]))
 
    for i in range(len(files)):
        filename=pathIn + files[i]
        #reading each files
        img = cv2.imread(filename)
        height, width, layers = img.shape
        size = (width,height)
        print(filename)
        #inserting the frames into an image array
        frame_array.append(img)
 
    out = cv2.VideoWriter(pathOut,cv2.VideoWriter_fourcc(*'DIVX'), fps, size)
 
    for i in range(len(frame_array)):
        # writing to a image array
        out.write(frame_array[i])
    out.release()
    
pathIn= './peds/'
pathOut = './peds/video.avi'
fps = 25.0
convert_frames_to_video(pathIn, pathOut, fps)
# Out:
# ./peds/frame_1.jpg
# ./peds/frame_2.jpg
# ./peds/frame_3.jpg
# ./peds/frame_4.jpg
# ./peds/frame_5.jpg
# ./peds/frame_6.jpg
# ./peds/frame_7.jpg
# ./peds/frame_8.jpg
# ./peds/frame_9.jpg
# ./peds/frame_10.jpg
# ./peds/frame_11.jpg
# ./peds/frame_12.jpg
# ./peds/frame_13.jpg
# ./peds/frame_14.jpg
# ./peds/frame_15.jpg
# ./peds/frame_16.jpg
# ./peds/frame_17.jpg
# ./peds/frame_18.jpg
# ./peds/frame_109.jpg
# ./peds/frame_110.jpg
# ./peds/frame_111.jpg
# ./peds/frame_112.jpg
# ./peds/frame_113.jpg
# ./peds/frame_114.jpg
# ./peds/frame_115.jpg
# ./peds/frame_116.jpg
# ./peds/frame_117.jpg
# ./peds/frame_118.jpg
# ./peds/frame_119.jpg
# ./peds/frame_120.jpg
# ./peds/frame_121.jpg
# ./peds/frame_122.jpg
# ./peds/frame_123.jpg
# ./peds/frame_124.jpg
# ./peds/frame_125.jpg
# ./peds/frame_126.jpg
# ./peds/frame_127.jpg
# ./peds/frame_128.jpg
# ./peds/frame_129.jpg
# ./peds/frame_130.jpg
# ./peds/frame_131.jpg
# ./peds/frame_132.jpg
# ./peds/frame_133.jpg
# ./peds/frame_134.jpg
# ./peds/frame_135.jpg
# ./peds/frame_136.jpg
# ./peds/frame_137.jpg
# ./peds/frame_138.jpg
# ./peds/frame_139.jpg
# ./peds/frame_140.jpg
# ./peds/frame_141.jpg
# ./peds/frame_142.jpg
# ./peds/frame_143.jpg
# ./peds/frame_144.jpg
# ./peds/frame_145.jpg
# ./peds/frame_146.jpg
# ./peds/frame_147.jpg
# ./peds/frame_148.jpg
# ./peds/frame_149.jpg
# ./peds/frame_150.jpg
# ./peds/frame_151.jpg
# ./peds/frame_152.jpg
# ./peds/frame_153.jpg
# ./peds/frame_154.jpg
# ./peds/frame_155.jpg
# ./peds/frame_156.jpg
# ./peds/frame_157.jpg
# ./peds/frame_158.jpg
# ./peds/frame_159.jpg
# ./peds/frame_160.jpg
# ./peds/frame_161.jpg
# ./peds/frame_162.jpg
# ./peds/frame_163.jpg
# ./peds/frame_164.jpg
# ./peds/frame_165.jpg
# ./peds/frame_166.jpg
# ./peds/frame_167.jpg
# ./peds/frame_168.jpg
# ./peds/frame_169.jpg
# ./peds/frame_170.jpg

# %% [markdown]
# O uso do algoritmo nativo para extração de plano de fundo do opencv teve resultados insatisfatórios por essa razão optou-se pelo uso de implementações suplementares disponíveis em https://github.com/andrewssobral/bgslibrary implementadas pelo pesquisador Andrew Sobral. A forma mais simples de usar a biblioteca é incluí-la em projeto OpenCV em C++, portanto o código do projeto implementado em C++ está incluido em anexo.

# %% [markdown]
# ### Resultados

# %%
# Imagem de referencia
img1 = plt.imread("results/frame_47.jpg")
showfig(img1)
# Exemplo de objetos encontrados pelo algoritmo do opencv
img1 = plt.imread("results/foreground_opencv_mog.jpg")
showfig(img1)
# Exemplo de objetos encontrados pelo algoritmo LBMixtureOfGaussians disponivel na biblioteca BGS
img1 = plt.imread("results/foreground_lbmog.jpg")
showfig(img1)
# Segmentação na imagem original
img1 = plt.imread("results/trackers.jpg")
showfig(img1)
